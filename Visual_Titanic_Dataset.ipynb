# %% [markdown]
# <a href="https://colab.research.google.com/github/vidjaydas/Data_Science_Python/blob/main/Visual_Titanic_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/content/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.size
# Out:
# 10692

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
data.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Survival - Survival (0 = No; 1 = Yes)
# Class - Passengers Class (1 = 1st; 2 = 2nd; 3 = 3rd) name - Name sex - Sex age - Age Sibsp - Number of Siblings/Spouses Aboard parch - Number of Parents/Children Aboard ticket - ticket number fare- Passenger Fare cabin - cabin Embarked - port of Embarkation ( C = Cherboug; Q = Queentown; S = Southampton)

# %%
data.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
data.groupby("Survived")[["Survived"]].count()
# Out:
#           Survived
# Survived
# 0              549
# 1              342

# %% [markdown]
# # Visual Exploration

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='Survived', y='Age', data=data)

# %%
 f, ax = plt.subplots(figsize= (10,5))
 sns.barplot(x='Sex', y='Survived', data=data)

# %%
f, ax = plt.subplots(figsize= (10,7))
sns.boxplot(x='Sex', y='Age', hue='Survived', data=data)

# %%
sns.barplot(x='Pclass', y='Survived', data=data)

# %%
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=data)

# %%
sns.barplot(x='SibSp', y='Survived', data=data)

# %%
sns.barplot(x='Parch', y='Survived', data=data)

# %%
survived = data.loc[data['Survived']==1,'Age'].dropna()
sns.distplot(survived)
plt.title('Survived');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#survived.skew()
survived.kurtosis()
# Out:
# -0.05760167400756311

# %%
not_survived = data.loc[data['Survived']==0,'Age'].dropna()
sns.distplot(not_survived)
plt.title('Not Survived');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
not_survived.kurtosis()
# Out:
# 0.28264561998717985

# %%
sns.pairplot(data.dropna());

# %%
# Pclass vs Survive
grid= sns.FacetGrid(data, col='Survived', row = 'Pclass', size =2.4, aspect=1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20, edgecolor='black')   
grid.add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(a=data[data['Embarked']=='C']['Survived'], bins=3, kde=False)
plt.title('Cherbourg')
plt.xticks([0,1])
plt.show()

plt.title('QueensTown')
sns.distplot(a= data[data['Embarked']=='Q']['Survived'], bins=3, kde=False)
#plt.xticks([0,1])        # X axis numbering
plt.show()

plt.title('Southampton')
sns.distplot(a= data[data['Embarked']=='S']['Survived'], bins=3, kde=False)
plt.xticks([0,1])
plt.show()

# Most of the Passengers embarked from Southampton
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh', ax=axesbi[0,0], xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh', ax=axesbi[0,1], xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh', ax=axesbi[0,2], xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh', ax=axesbi[0,3], xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh', ax=axesbi[1,0], xlim=[0,1])
sns.boxplot(x='Survived', y="Age", data=data, ax=axesbi[1,1])
sns.boxplot(x='Survived', y='Fare', data=data, ax=axesbi[1,2])
