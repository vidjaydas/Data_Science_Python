# %% [markdown]
# <a href="https://colab.research.google.com/github/vidjaydas/Data_Science_Python/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# Creat your first MLP in Keras
from keras.models import Sequential   
from keras.layers import Dense     #Dense is neural network, i.e. no. hidden layer, no. of neurans etc
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
#load pima indians dataset
dataset = numpy.loadtxt('/content/pima-indians-diabetes.data.csv', delimiter = ',')
#split into input (X) and output(Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# Create model
model = Sequential()
model.add(Dense(12, input_dim =8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation= 'sigmoid'))

# %%
#Compile model
model.compile(loss= 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X,Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 14s 20ms/step - loss: 10.0414 - accuracy: 0.3656 - val_loss: 3.3809 - val_accuracy: 0.3228
# Epoch 2/250
# 26/26 [==============================] - 0s 2ms/step - loss: 2.7188 - accuracy: 0.3754 - val_loss: 1.6309 - val_accuracy: 0.5276
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 1.5706 - accuracy: 0.5015 - val_loss: 1.2445 - val_accuracy: 0.5394
# Epoch 4/250
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1783 - accuracy: 0.5404 - val_loss: 0.9911 - val_accuracy: 0.5197
# Epoch 5/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9711 - accuracy: 0.6040 - val_loss: 0.9112 - val_accuracy: 0.5197
# Epoch 6/250
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8282 - accuracy: 0.6154 - val_loss: 0.8662 - val_accuracy: 0.5709
# Epoch 7/250
# ...

# %%
#evaluate the model
scores = model.evaluate(X,Y)
print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5173 - accuracy: 0.7513
# accuracy: 75.13%
